# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %%
imdb111 = pd.read_csv(r'C:\Users\Neil\Desktop\IMDBmain.csv')

# %%
imdb111
# Out:
#                         Movie     Year Certificate  Runtime  \
# 0         Don't Worry Darling   I 2022           R      122
# 1               Devil in Ohio     2022      UA 16+      356
# 2                 The Sandman   2022–            A       45
# 3                        Nope     2022           A      130
# 4             Stranger Things   2016–           15       51
# ..                        ...      ...         ...      ...
# 589                 I See You  II 2019           R       98
# 590       La migliore offerta     2013           R      131
# 591  Martha Marcy May Marlene     2011           R      102
# 592               Dark Places     2015           R      113
# 593                       Eli   I 2019           R       98
#
#                         Genre  Rating       Vote  \
# 0    Drama, Mystery, Thriller     3.6     8568.0
# 1      Drama, Horror, Mystery     5.9     8568.0
# 2      Drama, Fantasy, Horror     7.8   113185.0
# ...

# %%
imdb111.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Movie        594 non-null    object
#  1   Year         594 non-null    object
#  2   Certificate  594 non-null    object
#  3   Runtime      594 non-null    int64
#  4   Genre        594 non-null    object
#  5   Rating       594 non-null    float64
#  6   Vote         594 non-null    float64
#  7   Stars        594 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 37.2+ KB

# %%
imdb111['Stars'] = imdb111['Stars'].str.replace("[|'|]","")
# Out:
# C:\Users\Neil\AppData\Local\Temp\ipykernel_9876\1681550591.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   imdb111['Stars'] = imdb111['Stars'].str.replace("[|'|]","")

# %%
imdb111
# Out:
#                         Movie     Year Certificate  Runtime  \
# 0         Don't Worry Darling   I 2022           R      122
# 1               Devil in Ohio     2022      UA 16+      356
# 2                 The Sandman   2022–            A       45
# 3                        Nope     2022           A      130
# 4             Stranger Things   2016–           15       51
# ..                        ...      ...         ...      ...
# 589                 I See You  II 2019           R       98
# 590       La migliore offerta     2013           R      131
# 591  Martha Marcy May Marlene     2011           R      102
# 592               Dark Places     2015           R      113
# 593                       Eli   I 2019           R       98
#
#                         Genre  Rating       Vote  \
# 0    Drama, Mystery, Thriller     3.6     8568.0
# 1      Drama, Horror, Mystery     5.9     8568.0
# 2      Drama, Fantasy, Horror     7.8   113185.0
# ...

# %%
imdb111.Stars=imdb111.Stars.str.replace("[ |]","")
# Out:
# C:\Users\Neil\AppData\Local\Temp\ipykernel_9876\4078237956.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   imdb111.Stars=imdb111.Stars.str.replace("[ |]","")

# %%
imdb111
# Out:
#                         Movie     Year Certificate  Runtime  \
# 0         Don't Worry Darling   I 2022           R      122
# 1               Devil in Ohio     2022      UA 16+      356
# 2                 The Sandman   2022–            A       45
# 3                        Nope     2022           A      130
# 4             Stranger Things   2016–           15       51
# ..                        ...      ...         ...      ...
# 589                 I See You  II 2019           R       98
# 590       La migliore offerta     2013           R      131
# 591  Martha Marcy May Marlene     2011           R      102
# 592               Dark Places     2015           R      113
# 593                       Eli   I 2019           R       98
#
#                         Genre  Rating       Vote  \
# 0    Drama, Mystery, Thriller     3.6     8568.0
# 1      Drama, Horror, Mystery     5.9     8568.0
# 2      Drama, Fantasy, Horror     7.8   113185.0
# ...

# %%
imdb111.Stars=imdb111.Stars.str.replace(r'\[|\]','')
# Out:
# C:\Users\Neil\AppData\Local\Temp\ipykernel_9876\2702675328.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   imdb111.Stars=imdb111.Stars.str.replace(r'\[|\]','')

# %% [markdown]
# # Final Dataframe After Cleaning Process

# %%
imdb111
# Out:
#                         Movie     Year Certificate  Runtime  \
# 0         Don't Worry Darling   I 2022           R      122
# 1               Devil in Ohio     2022      UA 16+      356
# 2                 The Sandman   2022–            A       45
# 3                        Nope     2022           A      130
# 4             Stranger Things   2016–           15       51
# ..                        ...      ...         ...      ...
# 589                 I See You  II 2019           R       98
# 590       La migliore offerta     2013           R      131
# 591  Martha Marcy May Marlene     2011           R      102
# 592               Dark Places     2015           R      113
# 593                       Eli   I 2019           R       98
#
#                         Genre  Rating       Vote  \
# 0    Drama, Mystery, Thriller     3.6     8568.0
# 1      Drama, Horror, Mystery     5.9     8568.0
# 2      Drama, Fantasy, Horror     7.8   113185.0
# ...

# %%
imdb111[imdb111['Certificate']=='18+']
# Out:
#                            Movie       Year Certificate  Runtime  \
# 124                       Gotham  2014–2019         18+       42
# 130  How to Get Away with Murder  2014–2020         18+       43
# 141                 Carnival Row     2019–          18+       56
# 226                     Watchmen       2019         18+      527
# 300                     Preacher  2016–2019         18+       60
#
#                          Genre  Rating      Vote  \
# 124       Action, Crime, Drama     7.8  229188.0
# 130      Crime, Drama, Mystery     8.1  150182.0
# 141      Crime, Drama, Fantasy     7.8   61869.0
# 226      Crime, Drama, Mystery     8.2  117747.0
# 300  Adventure, Drama, Fantasy     7.9   74927.0
#
#                               Stars
# 124    BenMcKenzie,JadaPinkettSmith
# 130           ViolaDavis,BillyBrown
# 141        JamieHarris,OrlandoBloom
# 226  ReginaKing,YahyaAbdul-MateenII
# 300         DominicCooper,JoeGilgun

# %%
imdb111[(imdb111['Certificate']=='18+') & (imdb111['Rating']>7.1) & (imdb111['Vote']>50000)]
# Out:
#                            Movie       Year Certificate  Runtime  \
# 124                       Gotham  2014–2019         18+       42
# 130  How to Get Away with Murder  2014–2020         18+       43
# 141                 Carnival Row     2019–          18+       56
# 226                     Watchmen       2019         18+      527
# 300                     Preacher  2016–2019         18+       60
#
#                          Genre  Rating      Vote  \
# 124       Action, Crime, Drama     7.8  229188.0
# 130      Crime, Drama, Mystery     8.1  150182.0
# 141      Crime, Drama, Fantasy     7.8   61869.0
# 226      Crime, Drama, Mystery     8.2  117747.0
# 300  Adventure, Drama, Fantasy     7.9   74927.0
#
#                               Stars
# 124    BenMcKenzie,JadaPinkettSmith
# 130           ViolaDavis,BillyBrown
# 141        JamieHarris,OrlandoBloom
# 226  ReginaKing,YahyaAbdul-MateenII
# 300         DominicCooper,JoeGilgun
